# %%
import pandas as pd

num_rows = 0
chunk_iter = pd.read_csv("../data/Total_Data_10Y.csv", chunksize=100000)
for chunk in chunk_iter:
    num_rows += len(chunk)
chunk.head()
# Out:
# C:\Users\wongh\AppData\Local\Temp\ipykernel_23932\3398581933.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# C:\Users\wongh\AppData\Local\Temp\ipykernel_23932\3398581933.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# C:\Users\wongh\AppData\Local\Temp\ipykernel_23932\3398581933.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# C:\Users\wongh\AppData\Local\Temp\ipykernel_23932\3398581933.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# C:\Users\wongh\AppData\Local\Temp\ipykernel_23932\3398581933.py:5: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# ...

# %%
chunk.dtypes
# Out:
# FL_DATE                   object
# OP_UNIQUE_CARRIER         object
# TAIL_NUM                  object
# ORIGIN_AIRPORT_SEQ_ID      int64
# ORIGIN_CITY_MARKET_ID      int64
# ORIGIN                    object
# ORIGIN_CITY_NAME          object
# DEST_AIRPORT_SEQ_ID        int64
# DEST_CITY_MARKET_ID        int64
# DEST                      object
# DEST_CITY_NAME            object
# DEP_TIME                 float64
# DEP_DELAY                float64
# TAXI_OUT                 float64
# TAXI_IN                  float64
# ARR_TIME                 float64
# ARR_DELAY                float64
# CANCELLED                float64
# CANCELLATION_CODE         object
# CARRIER_DELAY            float64
# WEATHER_DELAY            float64
# NAS_DELAY                float64
# SECURITY_DELAY           float64
# LATE_AIRCRAFT_DELAY      float64
# dtype: object
